# %% [markdown]
# # Poços de Petróleo e Gás no Brasil (até janeiro/2018)
#
# **Faculdade**: FATEC Jessen Vidal de São José dos Campos
# **Curso**: TBI004 - Projeto de Banco de Dados Não Estruturados (1º semestre de 2018)
#
# **Aluno**: Felipe Koblinger
# **Professor**: Me. Fernando Masanori Ashikaga
#
# **Dataset**: https://www.kaggle.com/dtommasini/oil-gas-wells-brazil
#
# ## Indíce
# 1. [Explorações](#1.-Explorações)
# 2. [Estados que mais utilizaram poços para explorações](#2.-Estados-que-mais-utilizaram-poços-para-explorações)
# 3. [Estados que mais utilizaram poços para produção](#3.-Estados-que-mais-utilizaram-poços-para-produção)
# 4. [Movimentações Anuais](#4.-Movimentações-Anuais)
# 5. [As empresas que mais utilizaram os poços para explorações](#5.-As-empresas-que-mais-utilizaram-os-poços-para-explorações)
# 6. [As empresas que mais utilizaram os poços para produção](#6.-As-empresas-que-mais-utilizaram-os-poços-para-produção)
# 7. [Poços que atrasaram sua conclusão](#7.-Poços-que-atrasaram-sua-conclusão)
# 8. [Mapa das escavações realizadas ao longo da história](#8.-Mapa-das-escavações-realizadas-ao-longo-da-história)
# 9. [Situação dos poços iniciados nos últimos 5 anos](#9.-Situação-dos-poços-iniciados-nos-últimos-5-anos)
# 10. [As sondas mais utilizadas nos poços brasileiros](#10.-As-sondas-mais-utilizadas-nos-poços-brasileiros)
# 11. [Profundidade dos poços](#11.-Profundidade-dos-poços)
# 12. [Poços terrestres e poços marítimos](#12.-Poços-terrestres-e-poços-marítimos)
# 13. [Bacias com mais atividades ao longo da história](#13.-Bacias-com-mais-atividades-ao-longo-da-história)
# 14. [Categorias com mais atividades ao longo da história](#14.-Categorias-com-mais-atividades-ao-longo-da-história)
# 15. [Estados com mais atividades de desenvolvimento ao longo da história](#15.-Estados-com-mais-atividades-de-desenvolvimento-ao-longo-da-história)

# %% [markdown]
# ### Configurações Iniciais

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Style
plt.style.use('Solarize_Light2')

# List all available themes (uncomment the line below)
#print(plt.style.available)

low_memory = False
# %matplotlib inline

# Setting retina display for plots
# %config InlineBackend.figure_format = 'retina'

pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %% [markdown]
# ### Carregando arquivo Excel e definindo DataFrame

# %%
filename = 'datasets/tabela_de_pocos_janeiro_2018.xlsx'
df = pd.read_excel(filename, sheet_name='Plan1')

# %% [markdown]
# ### Informações do DataFrame

# %%
df.shape
# Out:
# (29575, 59)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29575 entries, 0 to 29574
# Data columns (total 59 columns):
# POCO                          29575 non-null object
# CADASTRO                      29575 non-null int64
# OPERADOR                      26643 non-null object
# POCO_OPERADOR                 28870 non-null object
# ESTADO                        29575 non-null object
# BACIA                         29575 non-null object
# BLOCO                         26254 non-null object
# SIG_CAMPO                     24954 non-null object
# CAMPO                         24954 non-null object
# TERRA_MAR                     29575 non-null object
# POCO_POS_ANP                  29575 non-null object
# TIPO                          29575 non-null object
# CATEGORIA                     29575 non-null object
# RECLASSIFICACAO               27972 non-null object
# SITUACAO                      28751 non-null object
# INICIO                        29575 non-null datetime64[ns]
# TERMINO                       27729 non-null datetime64[ns]
# CONCLUSAO                     29311 non-null datetime64[ns]
# TITULARIDADE                  29575 non-null object
# LATITUDE_BASE_4C              29575 non-null object
# LONGITUDE_BASE_4C             29575 non-null object
# LATITUDE_BASE_DD              29575 non-null object
# LONGITUDE_BASE_DD             29575 non-null object
# DATUM_HORIZONTAL              29575 non-null object
# TIPO_DE_COORDENADA_DE_BASE    29575 non-null object
# DIRECAO                       29575 non-null object
# PROFUNDIDADE_VERTICAL_M       8701 non-null float64
# PROFUNDIDADE_SONDADOR_M       27793 non-null float64
# PROFUNDIDADE_MEDIDA_M         10311 non-null float64
# REFERENCIA_DE_PROFUNDIDADE    28870 non-null object
# MESA_ROTATIVA                 28870 non-null float64
# COTA_ALTIMETRICA_M            10920 non-null float64
# LAMINA_D_AGUA_M               13466 non-null float64
# DATUM_VERTICAL                13944 non-null object
# UNIDADE_ESTRATIGRAFICA        15312 non-null object
# GEOLOGIA_GRUPO_FINAL          4054 non-null object
# GEOLOGIA_FORMACAO_FINAL       4945 non-null object
# GEOLOGIA_MEMBRO_FINAL         617 non-null object
# CDPE                          7241 non-null object
# AGP                           6900 non-null object
# PC                            8206 non-null object
# PAG                           1032 non-null object
# PERFIS_CONVENCIONAIS          6519 non-null object
# DURANTE_PERFURACAO            2510 non-null object
# PERFIS_DIGITAIS               20696 non-null object
# PERFIS_PROCESSADOS            15 non-null object
# PERFIS_ESPECIAIS              714 non-null object
# AMOSTRA_LATERAL               752 non-null object
# SISMICA                       1620 non-null object
# TABELA_TEMPO_PROFUNDIDADE     832 non-null object
# DADOS_DIRECIONAIS             6090 non-null object
# TESTE_A_CABO                  3586 non-null object
# TESTE_DE_FORMACAO             571 non-null object
# CANHONEIO                     138 non-null object
# TESTEMUNHO                    379 non-null object
# GEOQUIMICA                    3146 non-null object
# SIG_SONDA                     28787 non-null object
# NOM_SONDA                     24716 non-null object
# DHA_ATUALIZACAO               29575 non-null datetime64[ns]
# dtypes: datetime64[ns](4), float64(6), int64(1), object(48)
# memory usage: 13.3+ MB

# %% [markdown]
# ### Exemplo dos dados contidos no DataFrame

# %%
df.sample(5)
# Out:
#                 POCO      CADASTRO   OPERADOR  POCO_OPERADOR ESTADO  \
# 18643  7MG  0174  BA  202400260700  Petrobras  7MG  0174  BA     BA
# 7889    7-FP-442D-RN   72100028444  Petrobras      7FP442DRN     RN
# 11219  7ET  0186  RN  721000172500  Petrobras  7ET  0186  RN     RN
# 15839  7MG  0047  BA  202400193900  Petrobras  7MG  0047  BA     BA
# 24274  3RUC 0003  AM  140200058400  Petrobras  3RUC 0003  AM     AM
#
#            BACIA BLOCO SIG_CAMPO            CAMPO TERRA_MAR POCO_POS_ANP  \
# 18643  Recôncavo    MG     MG             MIRANGA         T            N
# 7889    Potiguar   NaN     FP     FAZENDA POCINHO         T            S
# 11219   Potiguar    ET     ET            ESTREITO         T            N
# 15839  Recôncavo    MG     MG             MIRANGA         T            N
# 24274   Solimões   RUC     RUC          RIO URUCU         T            N
#
#                TIPO        CATEGORIA  \
# 18643  Explotatório  Desenvolvimento
# 7889   Explotatório  Desenvolvimento
# 11219  Explotatório  Desenvolvimento
# 15839  Explotatório  Desenvolvimento
# 24274  Exploratório         Extensão
#
#                                         RECLASSIFICACAO  \
# 18643                    PRODUTOR COMERCIAL DE PETRÓLEO
# 7889                     PRODUTOR COMERCIAL DE PETRÓLEO
# 11219                    PRODUTOR COMERCIAL DE PETRÓLEO
# 15839                  ABANDONADO POR ACIDENTE MECÂNICO
# 24274  EXTENSÃO PARA PETRÓLEO, GÁS NATURAL E CONDENSADO
#
#                                                 SITUACAO     INICIO  \
# 18643  EM INTERVENÇÃO PARA AVALIAÇÃO, COMPLETAÇÃO OU ... 1971-11-22
# 7889                                            PRODUTOR 2015-09-12
# 11219                                            INJETOR 1984-03-24
# 15839                         ABANDONADO DEFINITIVAMENTE 1966-05-25
# 24274                                           PRODUTOR 1987-08-29
#
#          TERMINO  CONCLUSAO TITULARIDADE LATITUDE_BASE_4C LONGITUDE_BASE_4C  \
# 18643 1971-12-14 1971-12-14      Público    -12:20:37,622     -38:12:40,997
# 7889  2015-09-17 2015-10-15      Público    -05:15:07,148     -36:32:26,856
# 11219 1984-03-24 1984-03-24      Público    -05:23:40,988     -36:53:44,401
# 15839 1966-06-08 1966-06-08      Público    -12:20:55,438     -38:11:56,329
# 24274 1987-11-14 1987-11-14      Público    -04:53:31,220     -65:19:05,862
#
#       LATITUDE_BASE_DD LONGITUDE_BASE_DD DATUM_HORIZONTAL  \
# 18643   -12,3437838888    -38,2113880555       SIRGAS2000
# 7889     -5,2519855555    -36,5407933333       SIRGAS2000
# 11219    -5,3947188888    -36,8956669444       SIRGAS2000
# 15839   -12,3487327777    -38,1989802777       SIRGAS2000
# 24274    -4,8920055555        -65,318295       SIRGAS2000
#
#       TIPO_DE_COORDENADA_DE_BASE     DIRECAO  PROFUNDIDADE_VERTICAL_M  \
# 18643                 Definitiva    Vertical                      NaN
# 7889                  Definitiva  Direcional                    452.8
# 11219                 Definitiva    Vertical                      NaN
# 15839                 Definitiva    Vertical                      NaN
# 24274                 Definitiva    Vertical                      NaN
#
#        PROFUNDIDADE_SONDADOR_M  PROFUNDIDADE_MEDIDA_M  \
# 18643                   1250.0                    NaN
# 7889                     471.7                  472.0
# 11219                    281.0                    NaN
# 15839                    401.6                    NaN
# 24274                   2599.0                    NaN
#
#       REFERENCIA_DE_PROFUNDIDADE  MESA_ROTATIVA  COTA_ALTIMETRICA_M  \
# 18643                         MR          69.30                 NaN
# 7889                          MR          19.21               14.26
# 11219                         MR          35.00                 NaN
# 15839                         MR          92.30                 NaN
# 24274                         MR          67.50                 NaN
#
#        LAMINA_D_AGUA_M DATUM_VERTICAL UNIDADE_ESTRATIGRAFICA  \
# 18643              NaN            NaN                 M CATU
# 7889               0.0             NM                    NaN
# 11219              NaN            NaN                MRCO. I
# 15839              NaN            NaN               F SAOSEB
# 24274              NaN            NaN               MRCO 110
#
#       GEOLOGIA_GRUPO_FINAL GEOLOGIA_FORMACAO_FINAL GEOLOGIA_MEMBRO_FINAL  \
# 18643                  NaN                     NaN                   NaN
# 7889                 Apodi                     Açu                   NaN
# 11219                  NaN                     NaN                   NaN
# 15839                  NaN                     NaN                   NaN
# 24274                  NaN                     NaN                   NaN
#
#          CDPE     AGP      PC  PAG PERFIS_CONVENCIONAIS DURANTE_PERFURACAO  \
# 18643     NaN     NaN     NaN  NaN                  NaN                NaN
# 7889   Existe     NaN     NaN  NaN               Existe                NaN
# 11219     NaN  Existe     NaN  NaN                  NaN                NaN
# 15839     NaN     NaN     NaN  NaN                  NaN                NaN
# 24274     NaN  Existe  Existe  NaN                  NaN                NaN
#
#       PERFIS_DIGITAIS PERFIS_PROCESSADOS PERFIS_ESPECIAIS AMOSTRA_LATERAL  \
# 18643          Existe                NaN              NaN             NaN
# 7889              NaN                NaN              NaN             NaN
# 11219          Existe                NaN              NaN             NaN
# 15839             NaN                NaN              NaN             NaN
# 24274          Existe                NaN              NaN             NaN
#
#       SISMICA TABELA_TEMPO_PROFUNDIDADE DADOS_DIRECIONAIS TESTE_A_CABO  \
# 18643     NaN                       NaN               NaN          NaN
# 7889      NaN                       NaN            Existe          NaN
# 11219     NaN                       NaN               NaN          NaN
# 15839     NaN                       NaN               NaN          NaN
# 24274     NaN                       NaN               NaN          NaN
#
#       TESTE_DE_FORMACAO CANHONEIO TESTEMUNHO GEOQUIMICA SIG_SONDA  \
# 18643               NaN       NaN        NaN        NaN     SC-51
# 7889                NaN       NaN        NaN        NaN    EBS-05
# 11219               NaN       NaN        NaN        NaN     SC-63
# 15839               NaN       NaN        NaN        NaN     SC-37
# 24274               NaN       NaN        NaN        NaN     SC-96
#
#                    NOM_SONDA     DHA_ATUALIZACAO
# 18643  SONDA CONVENCIONAL 51 2018-01-28 05:00:06
# 7889                  EBS-05 2018-01-28 05:00:06
# 11219  SONDA CONVENCIONAL 63 2018-01-28 05:00:06
# 15839  SONDA CONVENCIONAL 37 2018-01-28 05:00:06
# 24274  SONDA CONVENCIONAL 96 2018-01-28 05:00:06

# %% [markdown]
# ### Tratamento de dados no DataFrame

# %%
def convert_brazil_number(value):
    new_value = value.replace(',','.')
    return float(new_value)

# Pesquisa sobre Locale

df['LONGITUDE_BASE_DD'] = df['LONGITUDE_BASE_DD'].apply(convert_brazil_number)
df['LATITUDE_BASE_DD'] = df['LATITUDE_BASE_DD'].apply(convert_brazil_number)

df['DIFERENCA_TERMINO_CONCLUSAO'] = (df['TERMINO'] - df['CONCLUSAO']).dt.days

# %% [markdown]
# ## 1. Explorações
# - Explotatório: poços de produção
# - Exploratório: poços de exploração

# %%
df.groupby('TIPO').size().sort_values().plot(kind='barh');

# %% [markdown]
# ## 2. Estados que mais utilizaram poços para explorações

# %%
df.query('TIPO == "Exploratório"').groupby('ESTADO').size().sort_values().tail(10).plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ## 3. Estados que mais utilizaram poços para produção

# %%
df.query('TIPO == "Explotatório"').groupby('ESTADO').size().sort_values().tail(10).plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ## 4. Movimentações Anuais

# %%
exploration = df.query('TIPO == "Exploratório"').groupby(df['INICIO'].map(lambda x: x.year)).size()
production = df.query('TIPO == "Explotatório"').groupby(df['INICIO'].map(lambda x: x.year)).size()

exploration_plot = exploration.plot(color='#ff1493')
production_plot = production.plot(ax = exploration_plot, color='#03b7ff', figsize=(10,6))

production_plot.legend(loc='upper left', labels=['Exploratório', 'Explotatório (Produção)'], facecolor="#FFFFFF", edgecolor="#FFFFFF");

# %% [markdown]
# ### 5. As empresas que mais utilizaram os poços para explorações

# %%
df.query('TIPO == "Exploratório"').groupby('OPERADOR').size().sort_values().tail(20).plot(kind='barh', figsize=(10,6));

# %%
df.query('TIPO == "Exploratório" & OPERADOR != "Petrobras"').groupby('OPERADOR').size().sort_values().tail(20).plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ### 6. As empresas que mais utilizaram os poços para produção

# %%
df.query('TIPO == "Explotatório"').groupby('OPERADOR').size().sort_values().plot(kind='barh', figsize=(10,6));

# %%
df.query('TIPO == "Explotatório" & OPERADOR != "Petrobras"').groupby('OPERADOR').size().sort_values().plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ### 7. Poços que atrasaram sua conclusão

# %%
df.query('DIFERENCA_TERMINO_CONCLUSAO < 0')['DIFERENCA_TERMINO_CONCLUSAO'].count()
# Out:
# 7630

# %%
df.query('DIFERENCA_TERMINO_CONCLUSAO < 0').sort_values(by='DIFERENCA_TERMINO_CONCLUSAO').head(10) \
.loc[:, ['DIFERENCA_TERMINO_CONCLUSAO', 'POCO', 'OPERADOR', 'ESTADO', 'INICIO', 'TERMINO', 'CONCLUSAO']]
# Out:
#        DIFERENCA_TERMINO_CONCLUSAO           POCO   OPERADOR ESTADO  \
# 2444                       -2311.0   7-JND-22D-BA  Petrobras     BA
# 12285                      -2009.0     9-CG-9-RJS  Petrobras     RJ
# 28660                      -1696.0   1-BRSA-63-RN  Petrobras     RN
# 7571                       -1567.0  8-PPT-9HP-RJS  Petrobras     RJ
# 26983                      -1450.0   7-FBL-19D-BA  Petrobras     BA
# 3648                       -1278.0  8-JND-12DP-BA  Petrobras     BA
# 6596                       -1274.0  9-PPT-26D-RJS  Petrobras     RJ
# 8334                       -1201.0  7-PPT-25H-RJS  Petrobras     RJ
# 8393                       -1196.0  7-PPT-33H-RJS  Petrobras     RJ
# 26822                      -1178.0  9-MLL-19D-RJS  Petrobras     RJ
#
#           INICIO    TERMINO  CONCLUSAO
# 2444  2006-11-29 2006-12-08 2013-04-06
# 12285 2011-02-10 2011-04-20 2016-10-19
# 28660 2001-04-18 2001-05-24 2006-01-14
# 7571  2012-08-04 2012-08-08 2016-11-22
# 26983 2009-10-19 2009-10-29 2013-10-18
# 3648  2006-01-31 2006-02-16 2009-08-17
# 6596  2013-05-25 2013-05-28 2016-11-22
# 8334  2013-08-08 2013-08-09 2016-11-22
# 8393  2013-08-12 2013-08-14 2016-11-22
# 26822 2004-12-17 2005-01-05 2008-03-28

# %% [markdown]
# ### 8. Mapa das escavações realizadas ao longo da história

# %%
f, ax = plt.subplots(figsize=(8,8))

colors = np.where(df["TERRA_MAR"] == 'T','#ef2f4f','#420dab')

ax.scatter(df['LONGITUDE_BASE_DD'],
           df['LATITUDE_BASE_DD'],
           1, c=colors)

m = Basemap(llcrnrlat=-35, urcrnrlat=7,
            llcrnrlon=-77, urcrnrlon=-32, resolution='f')
m.ax = ax
m.readshapefile('shapefiles/brazil/BRUFE250GC_SIR', 'states', drawbounds=True)

m.drawcoastlines(color='#556655', linewidth=1);

#Folium

# %% [markdown]
# ### 9. Situação dos poços iniciados nos últimos 5 anos

# %%
df.query('INICIO > "2013-1-1"').groupby('SITUACAO').size().sort_values().plot(kind='barh',figsize=(10,6));

# %% [markdown]
# ### 10. As sondas mais utilizadas nos poços brasileiros

# %%
df.groupby('NOM_SONDA').size().sort_values().tail(10).plot(kind='barh',figsize=(10,6));

# %% [markdown]
# ### 11. Profundidade dos poços

# %%
df.sort_values(by='PROFUNDIDADE_MEDIDA_M', ascending=False).head(10) \
.loc[:, ['PROFUNDIDADE_MEDIDA_M', 'POCO', 'OPERADOR', 'ESTADO', 'INICIO', 'TERMINO', 'CONCLUSAO']]
# Out:
#        PROFUNDIDADE_MEDIDA_M             POCO            OPERADOR ESTADO  \
# 8944                 8080.20    7-PRG-49H-RJS  Statoil Brasil O&G     RJ
# 5400                 7633.40    1-REPF-7A-ESS      Repsol Sinopec     ES
# 8246                 7628.00  1-BRSA-329D-RJS           Petrobras     RJ
# 10154                7432.00    7-PRG-46H-RJS  Statoil Brasil O&G     RJ
# 6458                 7159.90   1-REPF-12D-RJS      Statoil Brasil     RJ
# 6672                 7104.40  1-BRSA-1063-SPS           Petrobras     SP
# 8663                 7080.00   1-BRSA-886-RJS           Petrobras     RJ
# 7079                 7075.63    8-PRG-39D-RJS  Statoil Brasil O&G     RJ
# 5969                 7057.00  1-BRSA-876A-SPS           Petrobras     SP
# 6789                 7045.00  3-REPF-15DA-RJS      Statoil Brasil     RJ
#
#           INICIO    TERMINO  CONCLUSAO
# 8944  2015-06-28 2015-08-21 2015-09-06
# 5400  2010-06-01 2010-07-18 2010-08-05
# 8246  2005-01-01 2006-03-30 2006-10-28
# 10154 2015-03-06 2015-05-07 2015-05-23
# 6458  2011-08-09 2012-01-10 2012-03-08
# 6672  2012-08-31 2013-05-20 2013-06-24
# 8663  2010-11-06 2012-05-02 2012-06-05
# 7079  2014-07-18 2014-09-25 2014-10-03
# 5969  2010-10-19 2011-09-09 2011-09-11
# 6789  2015-01-14 2015-03-09 2015-05-16

# %%
df['PROFUNDIDADE_MEDIDA_M'].mean()
# Out:
# 1571.915860731257

# %% [markdown]
# ### 12. Poços terrestres e poços marítimos

# %%
df.groupby('TERRA_MAR').size().sort_values().plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ### 13. Bacias com mais atividades ao longo da história

# %%
df.groupby('BACIA').size().sort_values().tail(10).plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ### 14. Categorias com mais atividades ao longo da história

# %%
df.groupby('CATEGORIA').size().sort_values().plot(kind='barh', figsize=(10,6));

# %% [markdown]
# ### 15. Estados com mais atividades de desenvolvimento ao longo da história

# %%
df.query('CATEGORIA == "Desenvolvimento"').groupby('ESTADO').size().sort_values().plot(kind='barh', figsize=(10,6));
